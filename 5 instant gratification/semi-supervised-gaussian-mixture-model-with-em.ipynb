# %% [markdown]
# > ---
# # Theory

# %% [markdown]
# In Gaussian Mixture model, we maximize likelihood function $P(X_{train}|\pi,\mu,\Sigma)$ about $\pi, \mu, \Sigma$ by using EM algorithm (here, $\pi$ means distribution parameter of label Y, $\mu$ and $\Sigma$ are set of mean vector and covariance matrix for each categories).
#
# In this competiton, we have $X_{train}, Y_{tain}, X_{test}$. Gaussian Mixture model can treat $X_{train}, X_{test}$, and QDA (and other normal supervised model) can treat $X_{train}, Y_{train}$. Neither of them can treat $X_{train}, Y_{tain}, X_{test}$ at the same time.
#
# Then I tried to modify EM algorithm for Gaussian Mixture as to treat these at the same time. Equations are slightly complicated, but result is not so difficult. Please see chapter 9 of PRML book for detail (I used notation Z for representation of label-variable instead of Y, because I deduct formulas based on PRML).

# %% [markdown]
# $$
# \begin{align}
# P(X_{train},Y_{train},X_{test}|\pi,\mu,\Sigma)
# &= P(X_{train},Y_{train}|\pi,\mu,\Sigma)P(X_{test}|\pi,\mu,\Sigma) \\
# &= \Pi_{n=1}^{N_{train}}(\Pi_{k=1}^K \pi_k^{z_{nk}} N(x_n|\mu_k,\Sigma_k)^{z_{nk}})
# \Pi_{n=1}^{N_{test}}\Sigma_{k=1}^K \pi_k N(x_n|\mu_k,\Sigma_k)
# \end{align}
# $$
# and take log of this becomes below (log-likelihood).
# $$
# \log P = \Sigma_{n=1}^{N_{train}}\Sigma_{k=1}^K z_{nk}(\log \pi_k + \log N(x_n|\mu_k,\Sigma_k))
# +\Sigma_{n=1}^{N_{test}}\log\Sigma_{k=1}^K \pi_k N(x_n|\mu_k,\Sigma_k)
# $$

# %% [markdown]
# take derivatives of this is
# $$
# \frac{\partial\log P}{\partial\mu_s}
# =\Sigma_{n=1}^{N_{train}}z_{ns}\Sigma^{-1}_s(x_n-\mu_s)
# +\Sigma_{n=1}^{N_{test}}\frac{\pi_s N(x_n|\mu_s,\Sigma_s)}{\Sigma_{k=1}^K\pi_kN(x_n|\mu_k,\Sigma_k)}
# \Sigma^{-1}_s(x_n-\mu_s)=0
# $$
# therefore, if we assume $\Sigma_s$ is non-singular and define as below,
# $$
# \gamma(z_{ns}):=\frac{\pi_s N(x_n|\mu_s,\Sigma_s)}{\Sigma_{k=1}^K\pi_k N(x_n|\mu_k,\Sigma_k)}
# $$
# we get
# $$
# \mu_s = \frac{\Sigma_{n=1}^{N_{train}}z_{ns}x_n+\Sigma_{n=1}^{N_{test}}\gamma(z_{ns}x_n)}
# {\Sigma_{n=1}^{N_{train}}z_{ns}+\Sigma_{n=1}^{N_{test}}\gamma(z_{ns})}.
# $$

# %% [markdown]
# Let's compare this to normal Gaussian Mixture model.
# $$
# Normal Gaussian Mixture \\
# \mu_s = \frac{\Sigma_{n=1}^{N_{test}}\gamma(z_{ns}x_n)}
# {\Sigma_{n=1}^{N_{test}}\gamma(z_{ns})}.
# $$
# The meaning is very simple. We just use actual $z_{nk}$ instead of $\gamma(z_{ns})$ for taking weighted average step.

# %% [markdown]
# Then I finally get
# $$
# \begin{align}
# \mu_s &=\frac{\Sigma_{n=1}^{N_{train}}z_{ns}x_n+\Sigma_{n=1}^{N_{test}}\gamma(z_{ns}x_n)}
# {\Sigma_{n=1}^{N_{train}}z_{ns}+\Sigma_{n=1}^{N_{test}}\gamma(z_{ns})} \\
# \Sigma_s &=\frac{\Sigma_{n=1}^{N_{train}}z_{ns}(x_n-\mu_s)(x_n-\mu_s)^T+\Sigma_{n=1}^{N_{test}}\gamma(z_{ns}(x_n-\mu_s)(x_n-\mu_s)^T)}
# {\Sigma_{n=1}^{N_{train}}z_{ns}+\Sigma_{n=1}^{N_{test}}\gamma(z_{ns})} \\
# \pi_s &=\frac{\Sigma_{n=1}^{N_{train}}z_{ns}+\Sigma_{n=1}^{N_{test}}\gamma(z_{ns})}
# {\Sigma_t(\Sigma_{n=1}^{N_{train}}z_{nt}+\Sigma_{n=1}^{N_{test}}\gamma(z_{nt}))}
# \end{align}
# $$
# (Sorry, I deduct other than $\mu_s$ intuitively, then they may be wrong).

# %% [markdown]
# ---
# # Load Data

# %%
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

df_train = pd.read_csv('../input/train.csv')
df_test = pd.read_csv('../input/test.csv')

wcrms = df_train['wheezy-copper-turtle-magic'].unique()

# %% [markdown]
# ---
# # Modeling

# %%
import numpy as np
from scipy import stats

class SSGaussianMixture(object):
    def __init__(self, n_features, n_categories):
        self.n_features = n_features
        self.n_categories = n_categories
        
        self.mus = np.array([np.random.randn(n_features)]*n_categories)
        self.sigmas = np.array([np.eye(n_features)]*n_categories)
        self.pis = np.array([1/n_categories]*n_categories)
        
        
    def fit(self, X_train, y_train, X_test, threshold=0.00001, max_iter=100):
        Z_train = np.eye(self.n_categories)[y_train] 
        
        for i in range(max_iter):
        # EM algorithm
            # M step
            Z_test = np.array([self.gamma(X_test, k) for k in range(self.n_categories)]).T
            Z_test /= Z_test.sum(axis=1, keepdims=True)
        
            # E step
            datas = [X_train, Z_train, X_test, Z_test]
            mus = np.array([self._est_mu(k, *datas) for k in range(self.n_categories)])
            sigmas = np.array([self._est_sigma(k, *datas) for k in range(self.n_categories)])
            pis = np.array([self._est_pi(k, *datas) for k in range(self.n_categories)])
            
            diff = max(np.max(np.abs(mus-self.mus)), 
                       np.max(np.abs(sigmas-self.sigmas)), 
                       np.max(np.abs(pis-self.pis)))
            #print(diff)
            self.mus = mus
            self.sigmas = sigmas
            self.pis = pis
            if diff<threshold:
                break
                
                
    def predict_proba(self, X):
        Z_pred = np.array([self.gamma(X, k) for k in range(self.n_categories)]).T
        Z_pred /= Z_pred.sum(axis=1, keepdims=True)
        return Z_pred


    def gamma(self, X, k):
        # X is input vectors, k is feature index
        return stats.multivariate_normal.pdf(X, mean=self.mus[k], cov=self.sigmas[k])
        
    def _est_mu(self, k, X_train, Z_train, X_test, Z_test):
        mu = (Z_train[:,k]@X_train + Z_test[:,k]@X_test).T / \
                 (Z_train[:,k].sum() + Z_test[:,k].sum())
        return mu
    
    def _est_sigma(self, k, X_train, Z_train, X_test, Z_test):
        cmp1 = (X_train-self.mus[k]).T@np.diag(Z_train[:,k])@(X_train-self.mus[k])
        cmp2 = (X_test-self.mus[k]).T@np.diag(Z_test[:,k])@(X_test-self.mus[k])
        sigma = (cmp1+cmp2) / (Z_train[:,k].sum() + Z_test[:k].sum())
        return sigma
        
    def _est_pi(self, k, X_train, Z_train, X_test, Z_test):
        pi = (Z_train[:,k].sum() + Z_test[:,k].sum()) / \
                 (Z_train.sum() + Z_test.sum())
        return pi

# %%
# Below is just a lapper object.

from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold

class BaseClassifier(object):
    def __init__(self):
        self.preprocess = Pipeline([('vt', VarianceThreshold(threshold=2)), ('scaler', StandardScaler())])
 

    def fit(self, X_train, y_train, X_test, cv_qda=2, cv_meta=2):
        X_train_org = X_train
        self.preprocess_tune(np.vstack([X_train, X_test]))
        X_train = self.preprocess.transform(X_train)
        X_test = self.preprocess.transform(X_test)
        
        self.cgm = SSGaussianMixture(n_features=X_train.shape[1], n_categories=2)
        self.validation(X_train_org, y_train)
        self.cgm.fit(X_train, y_train, X_test)

    
    def predict(self, X):
        X = self.preprocess.transform(X)
        return self.cgm.predict_proba(X)[:,1]
    
    
    def preprocess_tune(self, X):
        self.preprocess.fit(X)
                
        
    def validation(self, X, y):
        X = self.preprocess.transform(X)
        kf = KFold(n_splits=3, shuffle=True)
        scores = []
        for train_index, test_index in kf.split(X):
            X_train, X_test = X[train_index], X[test_index]
            y_train, y_test = y[train_index], y[test_index]
            self.cgm.fit(X_train, y_train, X_test)
            y_pred = self.cgm.predict_proba(X_test)[:,1]
            scores.append(roc_auc_score(y_test, y_pred))
        self.score = np.array(scores).mean()
        print('validation score = ', self.score)

# %%
df_train_sample = df_train[df_train['wheezy-copper-turtle-magic']==wcrms[3]]
X_train_sample = df_train_sample.drop(['id', 'target', 'wheezy-copper-turtle-magic'], axis=1).values
y_train_sample = df_train_sample['target'].values

df_test_sample = df_test[df_test['wheezy-copper-turtle-magic']==wcrms[3]]
X_test_sample = df_test_sample.drop(['id', 'wheezy-copper-turtle-magic'], axis=1).values

# %%
bc = BaseClassifier()
bc.fit(X_train_sample, y_train_sample, X_test_sample)
# Out:
# validation score =  0.9711470469469882

# %%
class ConsolEstimator(object):
    def __init__(self, ids):
        self.clfs = {}
        self.id_column = 'wheezy-copper-turtle-magic'
        self.ids = ids
        
        
    def predict(self, df_X):
        y_pred = np.zeros(shape=(len(df_X)))
        for id in df_X[self.id_column].unique():
            id_rows = (df_X[self.id_column]==id)
            X = df_X.drop(['id', self.id_column], axis=1).values[id_rows]
            y_pred[id_rows] = self.clfs[id].predict(X)
        return y_pred
            
        
    def fit(self, df_train, df_test):
        for i, id in enumerate(self.ids):
            print(i, 'th training...')
            df_train_id = df_train[df_train[self.id_column]==id]
            df_test_id = df_test[df_test[self.id_column]==id]
            if len(df_train_id)==0 or len(df_test_id)==0:
                continue
            
            X_train = df_train_id.drop(['id', 'target', self.id_column], axis=1).values
            y_train = df_train_id['target'].values
            X_test = df_test_id.drop(['id', self.id_column], axis=1).values
            
            self.clfs[id] = BaseClassifier()
            self.clfs[id].fit(X_train, y_train, X_test)
            
        print('mean score = ', np.array([clf.score for clf in self.clfs.values()]).mean())

# %%
ce = ConsolEstimator(ids=wcrms)
ce.fit(df_train, df_test)
# Out:
# 0 th training...
# validation score =  0.9478242204745962
# 1 th training...
# validation score =  0.9591406507817898
# 2 th training...
# validation score =  0.9619554350593779
# 3 th training...
# validation score =  0.9700546301092244
# 4 th training...
# validation score =  0.9592800733636414
# 5 th training...
# validation score =  0.9452161137149783
# 6 th training...
# validation score =  0.969349211535541
# 7 th training...
# validation score =  0.9630749669449102
# 8 th training...
# validation score =  0.9638470703672554
# 9 th training...
# validation score =  0.9637347474197314
# 10 th training...
# validation score =  0.9802458847047263
# 11 th training...
# validation score =  0.9644841587646885
# 12 th training...
# validation score =  0.9630157397117017
# 13 th training...
# validation score =  0.9511988940820197
# 14 th training...
# validation score =  0.9744691627452476
# 15 th training...
# validation score =  0.9609040187145785
# 16 th training...
# validation score =  0.9697937734504604
# 17 th training...
# validation score =  0.9659163004203205
# 18 th training...
# validation score =  0.9525325378038555
# 19 th training...
# validation score =  0.9787886424292714
# 20 th training...
# validation score =  0.956662739546104
# 21 th training...
# validation score =  0.9632907386069359
# 22 th training...
# validation score =  0.9794526086899727
# 23 th training...
# validation score =  0.9645183816759945
# 24 th training...
# validation score =  0.9614860350773812
# 25 th training...
# validation score =  0.9574288314729062
# 26 th training...
# validation score =  0.9597165760398396
# 27 th training...
# validation score =  0.9747739346100337
# 28 th training...
# validation score =  0.9712536967959128
# 29 th training...
# validation score =  0.9576431778629764
# 30 th training...
# validation score =  0.9678323568062179
# 31 th training...
# validation score =  0.9730145225214512
# 32 th training...
# validation score =  0.9758873998826928
# 33 th training...
# validation score =  0.944196880366484
# 34 th training...
# validation score =  0.9516411443494777
# 35 th training...
# validation score =  0.9673754482141499
# 36 th training...
# validation score =  0.9676628074185109
# 37 th training...
# validation score =  0.9543428855933906
# 38 th training...
# validation score =  0.9682517159127849
# 39 th training...
# validation score =  0.9627549442399549
# 40 th training...
# validation score =  0.9706285986247377
# 41 th training...
# validation score =  0.9642791772480636
# 42 th training...
# validation score =  0.964911074124266
# 43 th training...
# validation score =  0.9692228867631353
# 44 th training...
# validation score =  0.9699072059187924
# 45 th training...
# validation score =  0.9612767608031207
# 46 th training...
# validation score =  0.9739711901002224
# 47 th training...
# validation score =  0.9783881244595771
# 48 th training...
# validation score =  0.9811234387451182
# 49 th training...
# validation score =  0.947622303755084
# 50 th training...
# validation score =  0.936548435787253
# 51 th training...
# validation score =  0.9596742021276596
# 52 th training...
# validation score =  0.9608738544265552
# 53 th training...
# validation score =  0.9694155282335456
# 54 th training...
# validation score =  0.9559471861205578
# 55 th training...
# validation score =  0.9687710418544572
# 56 th training...
# validation score =  0.9601431430235778
# 57 th training...
# validation score =  0.9678672256221118
# 58 th training...
# validation score =  0.9832925666704044
# 59 th training...
# validation score =  0.9594099081346457
# 60 th training...
# validation score =  0.9716286255237653
# 61 th training...
# validation score =  0.9673382447125327
# 62 th training...
# 260 th training...
# validation score =  0.9516703215280754
# 261 th training...
# validation score =  0.9618746863700377
# 262 th training...
# validation score =  0.9660593593887746
# 263 th training...
# validation score =  0.9674448354144017
# 264 th training...
# validation score =  0.9784658143134681
# 265 th training...
# validation score =  0.9724188418949579
# 266 th training...
# validation score =  0.9596368993171206
# 267 th training...
# validation score =  0.9759849519725469
# 268 th training...
# validation score =  0.9681291624300196
# 269 th training...
# validation score =  0.9608782293556999
# 270 th training...
# validation score =  0.964616741360984
# 271 th training...
# validation score =  0.9547808543540558
# 272 th training...
# validation score =  0.9725587106009798
# 273 th training...
# validation score =  0.9691933560893107
# 274 th training...
# validation score =  0.9715733637895744
# 275 th training...
# validation score =  0.9519221786907944
# 276 th training...
# validation score =  0.9656040386688716
# 277 th training...
# validation score =  0.937483067774715
# 278 th training...
# validation score =  0.963214049180242
# 279 th training...
# validation score =  0.9746444155653101
# 280 th training...
# validation score =  0.9615902865814493
# 281 th training...
# validation score =  0.9663646748286118
# 282 th training...
# validation score =  0.949520747138506
# 283 th training...
# validation score =  0.9636386306888852
# 284 th training...
# validation score =  0.9631467474763467
# 285 th training...
# validation score =  0.9654583869323307
# 286 th training...
# validation score =  0.9529360169541459
# 287 th training...
# validation score =  0.9558863350212025
# 288 th training...
# validation score =  0.9740135154746161
# 289 th training...
# validation score =  0.9661729996453069
# 290 th training...
# validation score =  0.9663739471975598
# 291 th training...
# validation score =  0.9783953037494504
# 292 th training...
# validation score =  0.9640458778225781
# 293 th training...
# validation score =  0.9457997817287325
# 294 th training...
# validation score =  0.9710821531232217
# 295 th training...
# validation score =  0.9806307747236244
# 296 th training...
# validation score =  0.9538837451995944
# 297 th training...
# validation score =  0.962526862678482
# 298 th training...
# validation score =  0.9623950744984809
# 299 th training...
# validation score =  0.9471578515135683
# 300 th training...
# validation score =  0.9614606695178983
# 301 th training...
# validation score =  0.9597549042532713
# 302 th training...
# validation score =  0.9650513439475384
# 303 th training...
# validation score =  0.9727388570908588
# 304 th training...
# validation score =  0.9579726237077185
# 305 th training...
# validation score =  0.9713536867435636
# 306 th training...
# validation score =  0.9660534481949169
# 307 th training...
# validation score =  0.9444446298882953
# 308 th training...
# validation score =  0.9544741404263887
# 309 th training...
# validation score =  0.9686191605895544
# 310 th training...
# validation score =  0.9582931424710232
# 311 th training...
# validation score =  0.9661803513617869
# 312 th training...
# validation score =  0.9783595929507407
# 313 th training...
# validation score =  0.9861668102504098
# 314 th training...
# validation score =  0.9775839801749795
# 315 th training...
# validation score =  0.9574492609082467
# 316 th training...
# validation score =  0.9629735836959963
# 317 th training...
# validation score =  0.955352170330475
# 318 th training...
# validation score =  0.977686209991521
# 319 th training...
# validation score =  0.975467894413247
# 320 th training...
# validation score =  0.9558709305502759
# 321 th training...
# validation score =  0.9655916764869029
# 322 th training...
# validation score =  0.9655045860610728
# 323 th training...
# validation score =  0.9516719236573726
# 324 th training...
# validation score =  0.9502046687756524
# 325 th training...
# validation score =  0.9728870467301726
# validation score =  0.9742805937066613
# 392 th training...
# validation score =  0.979996634240531
# 393 th training...
# validation score =  0.970785031206606
# 394 th training...
# validation score =  0.9462331249395864
# 395 th training...
# validation score =  0.9696956963649779
# 396 th training...
# validation score =  0.9658736095945398
# 397 th training...
# validation score =  0.9624733513880699
# 398 th training...
# validation score =  0.9593553747382288
# 399 th training...
# validation score =  0.9670140486311326
# 400 th training...
# validation score =  0.9689746515071774
# 401 th training...
# validation score =  0.9748972545667347
# 402 th training...
# validation score =  0.970900325430558
# 403 th training...
# validation score =  0.9552124212530564
# 404 th training...
# validation score =  0.9651577180988946
# 405 th training...
# validation score =  0.9731698508744729
# 406 th training...
# validation score =  0.9561347602243515
# 407 th training...
# validation score =  0.9624075839905597
# 408 th training...
# validation score =  0.9660147229225471
# 409 th training...
# validation score =  0.9551550898312454
# 410 th training...
# validation score =  0.9492856715798111
# 411 th training...
# validation score =  0.9720612088953472
# 412 th training...
# validation score =  0.9592934239354703
# 413 th training...
# validation score =  0.9740200062691584
# 414 th training...
# validation score =  0.9659993681788771
# 415 th training...
# validation score =  0.9503655564128427
# 416 th training...
# validation score =  0.9637715918900166
# 417 th training...
# validation score =  0.9681620899716262
# 418 th training...
# validation score =  0.9738715848889061
# 419 th training...
# validation score =  0.9667561460184185
# 420 th training...
# validation score =  0.9570856017477388
# 421 th training...
# validation score =  0.96726686710275
# 422 th training...
# validation score =  0.9729568884601276
# 423 th training...
# validation score =  0.9788289356907028
# 424 th training...
# validation score =  0.9814815145613109
# 425 th training...
# validation score =  0.9712874358509042
# 426 th training...
# validation score =  0.9768915831093633
# 427 th training...
# validation score =  0.9775678426760958
# 428 th training...
# validation score =  0.9779730781582384
# 429 th training...
# validation score =  0.9652971007318834
# 430 th training...
# validation score =  0.9753360807308438
# 431 th training...
# validation score =  0.9561107772968126
# 432 th training...
# validation score =  0.9792419126164232
# 433 th training...
# validation score =  0.964748738054277
# 434 th training...
# validation score =  0.9751960015780549
# 435 th training...
# validation score =  0.9553977690244206
# 436 th training...
# validation score =  0.9654448914585386
# 437 th training...
# validation score =  0.9702747535355605
# 438 th training...
# validation score =  0.9694748254132882
# 439 th training...
# validation score =  0.9635892381644015
# 440 th training...
# validation score =  0.9773615204367765
# 441 th training...
# validation score =  0.9488984829775206
# 442 th training...
# validation score =  0.972981466213669
# 443 th training...
# validation score =  0.977678434671247
# 444 th training...
# validation score =  0.954399766041468
# 445 th training...
# validation score =  0.972155451327818
# 446 th training...
# validation score =  0.9658976984647483
# 447 th training...
# validation score =  0.9453399304480029
# 448 th training...
# validation score =  0.9466809995112451
# 449 th training...
# validation score =  0.9687569080617333
# 450 th training...
# validation score =  0.9725301852953706
# 451 th training...
# validation score =  0.9680523838465064
# 452 th training...
# validation score =  0.966478287092205
# 453 th training...
# validation score =  0.9704534367216988
# 454 th training...
# validation score =  0.9742013905230866
# 455 th training...
# validation score =  0.9697518005394675
# 456 th training...
# validation score =  0.9547656639487311
# 457 th training...
# validation score =  0.9758555433267443
# 458 th training...
# validation score =  0.9724600712013626
# 459 th training...
# validation score =  0.9733174040687502
# 460 th training...
# validation score =  0.9562587164220702
# 461 th training...
# validation score =  0.9575277617107858
# 462 th training...
# validation score =  0.9609551258232291
# 463 th training...
# validation score =  0.968867709246709
# 464 th training...
# validation score =  0.9531257907332584
# 465 th training...
# validation score =  0.9721192520843251
# 466 th training...
# validation score =  0.9714357726439875
# 467 th training...
# validation score =  0.9652104921623818
# 468 th training...
# validation score =  0.9519842181060619
# 469 th training...
# validation score =  0.9341674131209015
# 470 th training...
# validation score =  0.9700209053073316
# 471 th training...
# validation score =  0.9513728488999522
# 472 th training...
# validation score =  0.9798117832611933
# 473 th training...
# validation score =  0.9592700265215374
# 474 th training...
# validation score =  0.963089179316357
# 475 th training...
# validation score =  0.9766632794693951
# 476 th training...
# validation score =  0.9720239555013331
# 477 th training...
# validation score =  0.9764579204979272
# 478 th training...
# validation score =  0.9496382943416383
# 479 th training...
# validation score =  0.9762300971044038
# 480 th training...
# validation score =  0.9753860224019933
# 481 th training...
# validation score =  0.9607134680995046
# 482 th training...
# validation score =  0.9622216975172403
# 483 th training...
# validation score =  0.956193676792219
# 484 th training...
# validation score =  0.9632995914434148
# 485 th training...
# validation score =  0.9649750862731956
# 486 th training...
# validation score =  0.9705539857778679
# 487 th training...
# validation score =  0.9499683444127888
# 488 th training...
# validation score =  0.9658441238688152
# 489 th training...
# validation score =  0.976416618913284
# 490 th training...
# validation score =  0.9854711794568268
# 491 th training...
# validation score =  0.9651414627111041
# 492 th training...
# validation score =  0.9585068527922527
# 493 th training...
# validation score =  0.9626638286788932
# 494 th training...
# validation score =  0.9734313882547694
# 495 th training...
# validation score =  0.9677428767088921
# 496 th training...
# validation score =  0.9747147366966945
# 497 th training...
# validation score =  0.972518430383599
# 498 th training...
# validation score =  0.9628694396825815
# 499 th training...
# validation score =  0.9751837365246679
# 500 th training...
# validation score =  0.9612539937018157
# 501 th training...
# validation score =  0.9568603728367089
# 502 th training...
# validation score =  0.9494535907540219
# 503 th training...
# validation score =  0.9594794974915208
# 504 th training...
# validation score =  0.9728658300486384
# 505 th training...
# validation score =  0.972155039672547
# 506 th training...
# validation score =  0.9798740337061179
# 507 th training...
# validation score =  0.9723374344269736
# 508 th training...
# validation score =  0.9593285835141471
# 509 th training...
# validation score =  0.963550557629505
# 510 th training...
# validation score =  0.9559764072082598
# 511 th training...
# validation score =  0.9685118193562353
# mean score =  0.9649141663521423

# %% [markdown]
# ---
# # Submission

# %%
y_pred = ce.predict(df_test)

# %%
df_submission = pd.concat([df_test['id'], pd.Series(y_pred, name='target')], axis=1)
df_submission.to_csv('submission.csv', index=False)

# %% [markdown]
# I tried hyper parameter tuning and bugging, but LB score didn't improve.
# When I used BayesianGaussianMixture instead of GaussianMixture in stacking, my CV score improved, then if we can treat above model in Bayesian, score may improve.
# But for me, treating Gauss-Wishart distribution is hard (sklean implementation of GayesianGaussianMixture can be used as a refference).
